# %%
#!pip install --upgrade tensorflow==1.15

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import SimpleRNNCell, RNN, Dense
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import pandas_datareader as pdr

# %%
df = pdr.get_data_yahoo('BTC-USD', start = '2019-01-01', end='2021-04-12')
df
# Out:
#                     High           Low  ...        Volume     Adj Close
# Date                                    ...
# 2019-01-01   3850.913818   3707.231201  ...  4.324201e+09   3843.520020
# 2019-01-02   3947.981201   3817.409424  ...  5.244857e+09   3943.409424
# 2019-01-03   3935.685059   3826.222900  ...  4.530215e+09   3836.741211
# 2019-01-04   3865.934570   3783.853760  ...  4.847965e+09   3857.717529
# 2019-01-05   3904.903076   3836.900146  ...  5.137610e+09   3845.194580
# ...                  ...           ...  ...           ...           ...
# 2021-04-07  58338.738281  55879.085938  ...  5.305386e+10  58323.953125
# 2021-04-08  58937.046875  57807.863281  ...  4.665521e+10  58245.003906
# 2021-04-09  61276.664062  58038.707031  ...  5.823847e+10  59793.234375
# 2021-04-10  60790.554688  59289.796875  ...  4.628025e+10  60204.964844
# 2021-04-12  60576.250000  59674.378906  ...  4.484514e+10  60146.726562
#
# [829 rows x 6 columns]

# %%
prices = df['Close'].values

# %%
train_prices, test_prices = train_test_split(prices, test_size = 0.2, shuffle = False)

# %%
#reshape jadi column matrix
train_prices = train_prices.reshape(-1, 1)
test_prices = test_prices.reshape(-1,1)

# %%
#preprocess
scaler = MinMaxScaler().fit(train_prices)
train_prices = scaler.transform(train_prices)
test_prices = scaler.transform(test_prices)

# %%
timestep = 64

# %%
def construct_dataset(in_prices):
    features = []
    targets = []
    for i in range(timestep, in_prices.shape[0]):
        features.append(
            in_prices[i - timestep : i]
        )
        targets.append(
            in_prices[i]
        )

    features = np.array(features, 'float32')
    targets = np.array(targets, 'float32')

    return features, targets

x_train, y_train = construct_dataset(train_prices)
x_test, y_test = construct_dataset(test_prices)

# %%
input_placeholder = tf.placeholder(tf.float32, [None, timestep, 1])
target_placeholder = tf.placeholder(tf.float32, [None, 1])

# %%
cell = SimpleRNNCell(64, 'relu')
rnn_layer = RNN(cell, dtype = tf.float32)
output_layer = Dense(1)

# %%
out_tensor = rnn_layer(input_placeholder)
out_tensor = output_layer(out_tensor)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %% [markdown]
# Training

# %%
#MSE
loss_tensor = tf.reduce_mean(0.5 * (out_tensor - target_placeholder) ** 2)

#Optional

rmse_tensor = tf.reduce_mean(tf.sqrt(0.5 * (out_tensor - target_placeholder) ** 2))

# %%
optimizer = tf.train.AdamOptimizer().minimize(loss_tensor)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
saver = tf.train.Saver()

# %%
num_epoch = 5000

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())

    train_dict = {
        input_placeholder: x_train,
        target_placeholder: y_train
    }

    test_dict = {
        input_placeholder: x_test,
        target_placeholder: y_test
    }

    best_loss = float('inf')

    for epoch in range(num_epoch):
        sess.run(optimizer, feed_dict=train_dict)

        # MSE
        loss = sess.run(loss_tensor, feed_dict=train_dict)
        val_loss = sess.run(loss_tensor, feed_dict=test_dict)

        # RMSE
        rmse = sess.run(rmse_tensor, feed_dict=train_dict)
        val_rmse = sess.run(rmse_tensor, feed_dict=test_dict)

        if val_loss < best_loss:
            best_loss = val_loss
            saver.save(sess, '/.best_model.ckpt')
        if epoch % 100 == 0:
            print(f'Epoch {epoch + 1} | Loss {loss:.4f} | Val_loss {val_loss:.4f} | RMSE {rmse:.4f} | val_rmse {val_rmse:.4f}')
# Out:
# Epoch 1 | Loss 0.1495 | Val_loss 9.0876 | RMSE 0.3604 | val_rmse 2.9382
# Epoch 101 | Loss 0.0008 | Val_loss 0.0529 | RMSE 0.0198 | val_rmse 0.1933
# Epoch 201 | Loss 0.0007 | Val_loss 0.0456 | RMSE 0.0180 | val_rmse 0.1781
# Epoch 301 | Loss 0.0007 | Val_loss 0.0390 | RMSE 0.0174 | val_rmse 0.1627
# Epoch 401 | Loss 0.0007 | Val_loss 0.0342 | RMSE 0.0169 | val_rmse 0.1500
# Epoch 501 | Loss 0.0006 | Val_loss 0.0309 | RMSE 0.0164 | val_rmse 0.1407
# Epoch 601 | Loss 0.0006 | Val_loss 0.0292 | RMSE 0.0160 | val_rmse 0.1356
# Epoch 701 | Loss 0.0006 | Val_loss 0.0280 | RMSE 0.0157 | val_rmse 0.1327
# Epoch 801 | Loss 0.0006 | Val_loss 0.0275 | RMSE 0.0153 | val_rmse 0.1313
# Epoch 901 | Loss 0.0006 | Val_loss 0.0272 | RMSE 0.0150 | val_rmse 0.1295
# Epoch 1001 | Loss 0.0005 | Val_loss 0.0269 | RMSE 0.0147 | val_rmse 0.1279
# Epoch 1101 | Loss 0.0005 | Val_loss 0.0271 | RMSE 0.0146 | val_rmse 0.1280
# Epoch 1201 | Loss 0.0005 | Val_loss 0.0276 | RMSE 0.0144 | val_rmse 0.1288
# Epoch 1301 | Loss 0.0005 | Val_loss 0.0281 | RMSE 0.0143 | val_rmse 0.1301
# Epoch 1401 | Loss 0.0005 | Val_loss 0.0292 | RMSE 0.0143 | val_rmse 0.1337
# Epoch 1501 | Loss 0.0005 | Val_loss 0.0301 | RMSE 0.0143 | val_rmse 0.1373
# Epoch 1601 | Loss 0.0005 | Val_loss 0.0320 | RMSE 0.0143 | val_rmse 0.1432
# Epoch 1701 | Loss 0.0005 | Val_loss 0.0490 | RMSE 0.0138 | val_rmse 0.1859
# Epoch 1801 | Loss 0.0005 | Val_loss 0.0593 | RMSE 0.0137 | val_rmse 0.2026
# Epoch 1901 | Loss 0.0004 | Val_loss 0.0780 | RMSE 0.0135 | val_rmse 0.2219
# Epoch 2001 | Loss 0.0004 | Val_loss 0.0876 | RMSE 0.0133 | val_rmse 0.2364
# Epoch 2101 | Loss 0.0004 | Val_loss 0.1574 | RMSE 0.0130 | val_rmse 0.3164
# Epoch 2201 | Loss 0.0004 | Val_loss 0.1541 | RMSE 0.0129 | val_rmse 0.3121
# Epoch 2301 | Loss 0.0004 | Val_loss 0.1676 | RMSE 0.0127 | val_rmse 0.3322
# Epoch 2401 | Loss 0.0004 | Val_loss 0.1820 | RMSE 0.0124 | val_rmse 0.3344
# Epoch 2501 | Loss 0.0003 | Val_loss 0.2069 | RMSE 0.0121 | val_rmse 0.3543
# Epoch 2601 | Loss 0.0003 | Val_loss 0.1974 | RMSE 0.0119 | val_rmse 0.3491
# Epoch 2701 | Loss 0.0003 | Val_loss 0.2261 | RMSE 0.0119 | val_rmse 0.3617
# Epoch 2801 | Loss 0.0003 | Val_loss 0.2344 | RMSE 0.0114 | val_rmse 0.3773
# Epoch 2901 | Loss 0.0003 | Val_loss 0.3627 | RMSE 0.0118 | val_rmse 0.3823
# Epoch 3001 | Loss 0.0003 | Val_loss 0.4408 | RMSE 0.0111 | val_rmse 0.4232
# Epoch 3101 | Loss 0.0003 | Val_loss 0.3042 | RMSE 0.0111 | val_rmse 0.4214
# Epoch 3201 | Loss 0.0003 | Val_loss 0.3564 | RMSE 0.0111 | val_rmse 0.4458
# Epoch 3301 | Loss 0.0003 | Val_loss 0.2955 | RMSE 0.0111 | val_rmse 0.4247
# Epoch 3401 | Loss 0.0003 | Val_loss 0.3165 | RMSE 0.0107 | val_rmse 0.4333
# Epoch 3501 | Loss 0.0003 | Val_loss 0.3005 | RMSE 0.0108 | val_rmse 0.4167
# Epoch 3601 | Loss 0.0003 | Val_loss 0.3133 | RMSE 0.0111 | val_rmse 0.4289
# Epoch 3701 | Loss 0.0003 | Val_loss 0.3318 | RMSE 0.0109 | val_rmse 0.4365
# Epoch 3801 | Loss 0.0003 | Val_loss 0.3477 | RMSE 0.0102 | val_rmse 0.4505
# Epoch 3901 | Loss 0.0003 | Val_loss 0.3456 | RMSE 0.0111 | val_rmse 0.4474
# Epoch 4001 | Loss 0.0002 | Val_loss 0.3493 | RMSE 0.0101 | val_rmse 0.4463
# Epoch 4101 | Loss 0.0003 | Val_loss 0.3550 | RMSE 0.0113 | val_rmse 0.4558
# Epoch 4201 | Loss 0.0003 | Val_loss 0.4088 | RMSE 0.0107 | val_rmse 0.4745
# Epoch 4301 | Loss 0.0002 | Val_loss 0.4034 | RMSE 0.0101 | val_rmse 0.4769
# Epoch 4401 | Loss 0.0003 | Val_loss 0.4660 | RMSE 0.0123 | val_rmse 0.5087
# Epoch 4501 | Loss 0.0002 | Val_loss 0.6258 | RMSE 0.0101 | val_rmse 0.5868
# Epoch 4601 | Loss 0.0002 | Val_loss 0.6045 | RMSE 0.0098 | val_rmse 0.5621
# Epoch 4701 | Loss 0.0002 | Val_loss 0.7364 | RMSE 0.0095 | val_rmse 0.6156
# Epoch 4801 | Loss 0.0002 | Val_loss 1.0015 | RMSE 0.0093 | val_rmse 0.7318
# Epoch 4901 | Loss 0.0002 | Val_loss 1.0564 | RMSE 0.0102 | val_rmse 0.7625

# %%
with tf.Session() as sess:
    saver.restore(sess, './best_model.ckpt')

    pred = sess.run(out_tensor, feed_dict ={input_placeholder:x})
    pred = scaler.inverse_transform(pred)

    print(f'Tomorrow BTC: {pred} USD')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-2ea9f3f5c71f> in <module>()
#       1 with tf.Session() as sess:
# ----> 2     saver.restore(sess, './best_model.ckpt')
#       3
#       4     pred = sess.run(out_tensor, feed_dict ={input_placeholder:x})
#       5     pred = scaler.inverse_transform(pred)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/training/saver.py in restore(self, sess, save_path)
#    1280     if not checkpoint_management.checkpoint_exists_internal(checkpoint_prefix):
#    1281       raise ValueError("The passed save_path is not a valid checkpoint: " +
# -> 1282                        checkpoint_prefix)
#    1283
#    1284     logging.info("Restoring parameters from %s", checkpoint_prefix)
#
# ValueError: The passed save_path is not a valid checkpoint: ./best_model.ckpt
