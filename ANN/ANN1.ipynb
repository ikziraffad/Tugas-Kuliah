# %% [markdown]
# #Input Output

# %%
print("Hello World!")
name = input('Enter your name: ')
# Out:
# Hello World!
# Enter your name: Daffa Rizki
# 'Daffa Rizki'

# %% [markdown]
# #Variable

# %%
age = 19
name = "Daffa Rizki Rizaly"
is_taken = True
None 
f"{name}, {age} years old"
# Out:
# 'Daffa Rizki Rizaly, 19 years old'

# %% [markdown]
# #Array/List

# %%
#list
buy_list = ['Game','nitro','mouse']

# %% [markdown]
# #Loop

# %%
for item in buy_list:
    print(item, end = ' test\n')
    print(10)
    
    for i in range(10):
            print(i+1)

# %% [markdown]
# #Selection

# %%
if age > 20:
    print("Eroi")
elif age > 10:
    print("Dame yo")
else:
    print('yada')
# Out:
# Dame yo

# %% [markdown]
# #Dictionary

# %% [markdown]
# #Function

# %%
def say_hello(input_name):
    print(f"Hello {input_name} World!!!")
    return 10
temp = say_hello('daffa')
# Out:
# Hello daffa World!!!

# %% [markdown]
# #Pandas

# %%
import pandas

# %%
df = pandas.read_csv('Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# #Numpy
