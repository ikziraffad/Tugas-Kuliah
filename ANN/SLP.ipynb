# %%
import numpy as np

# %%
input_data = [
              [0,0],
              [0,1],
              [1,0],
              [1,1]
]

target = [0, 1 , 1 , 1]

# %%
weight = np.random.normal(size = (2,1))

# %%
bias = np.random.normal(size = 1)

# %%
def feed_forward(inputs):
    value = np.matmul(inputs , weight)
    value += bias
    return activation_func(value)

# %%
def activation_func(x):
    if x > 0:
        return 1
    else:
        return 0

# %%
EPOCH = 100 
ALPHA = 0.1

# %%
for i in range(1, EPOCH + 1):
    randindex = np.random.randint(0, len(input_data))
    #Training
    train_data = input_data[randindex]
    predict_output = feed_forward(train_data)
    error = predict_output - target[randindex]
    #update Weight
    weight = weight - (np.array(train_data).reshape(2 , 1)*ALPHA * error)
    #update Bias
    bisa = bias - (ALPHA * error)
    if i % 20 == 0:
        correct_result = 0
        for i, test_data in enumerate(input_data):
            test_result = feed_forward(test_data)
            if test_result == target[i]:
                correct_result += 1
        print(f'Accuracy:{correct_result / len(input_data) * 100} %')
# Out:
# Accuracy:25.0 %
# Accuracy:75.0 %
# Accuracy:75.0 %
# Accuracy:75.0 %
# Accuracy:75.0 %

# %%
df = pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# #Preprocessing

# %%
input_data_2 = df[['SepalLengthCm','SepalWidthCm']]

target_data = df['Species']
target_data
from sklearn.preprocessing import OneHotEncoder
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object
